# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
ruta = 'Fifa_stats.csv'
df = pd.read_csv(ruta)
df.head()
# Out:
#    sofifa_id                            long_name         dob  age  \
# 0     158023       Lionel Andrés Messi Cuccittini  1987-06-24   32
# 1      20801  Cristiano Ronaldo dos Santos Aveiro  1985-02-05   34
# 2     190871        Neymar da Silva Santos Junior  1992-02-05   27
# 3     200389                            Jan Oblak  1993-01-07   26
# 4     183277                          Eden Hazard  1991-01-07   28
#
#   nationality                 club preferred_foot  height_cm  weight_kg  \
# 0   Argentina         FC Barcelona           Left        170         72
# 1    Portugal             Juventus          Right        187         83
# 2      Brazil  Paris Saint-Germain          Right        175         68
# 3    Slovenia      Atlético Madrid          Right        188         87
# 4     Belgium          Real Madrid          Right        175         74
#
#    overall  ...  mentality_penalties  mentality_composure  defending_marking  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Data columns (total 59 columns):
# sofifa_id                     18278 non-null int64
# long_name                     18278 non-null object
# dob                           18278 non-null object
# age                           18278 non-null int64
# nationality                   18278 non-null object
# club                          18278 non-null object
# preferred_foot                18278 non-null object
# height_cm                     18278 non-null int64
# weight_kg                     18278 non-null int64
# overall                       18278 non-null int64
# potential                     18278 non-null int64
# value_eur                     18278 non-null int64
# team_jersey_number            18038 non-null float64
# pace                          16242 non-null float64
# shooting                      16242 non-null float64
# passing                       16242 non-null float64
# ...

# %%
df.shape
# Out:
# (18278, 59)

# %%
df.shape[0]
# Out:
# 18278

# %%
df.shape[1]
# Out:
# 59

# %%
df.columns.values.tolist()
# Out:
# ['sofifa_id',
#  'long_name',
#  'dob',
#  'age',
#  'nationality',
#  'club',
#  'preferred_foot',
#  'height_cm',
#  'weight_kg',
#  'overall',
#  'potential',
#  'value_eur',
#  'team_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
# ...

# %%
df.dtypes
# Out:
# sofifa_id                       int64
# long_name                      object
# dob                            object
# age                             int64
# nationality                    object
# club                           object
# preferred_foot                 object
# height_cm                       int64
# weight_kg                       int64
# overall                         int64
# potential                       int64
# value_eur                       int64
# team_jersey_number            float64
# pace                          float64
# shooting                      float64
# passing                       float64
# dribbling                     float64
# defending                     float64
# physic                        float64
# gk_diving                     float64
# gk_handling                   float64
# gk_kicking                    float64
# gk_reflexes                   float64
# gk_speed                      float64
# gk_positioning                float64
# ...

# %%
df.shape
# Out:
# (18278, 59)

# %%
df.shape[0]
# Out:
# 18278

# %%
df.shape[1]
# Out:
# 59

# %%
df.columns.values.tolist()
# Out:
# ['sofifa_id',
#  'long_name',
#  'dob',
#  'age',
#  'nationality',
#  'club',
#  'preferred_foot',
#  'height_cm',
#  'weight_kg',
#  'overall',
#  'potential',
#  'value_eur',
#  'team_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
# ...

# %%
df.dtypes
# Out:
# sofifa_id                       int64
# long_name                      object
# dob                            object
# age                             int64
# nationality                    object
# club                           object
# preferred_foot                 object
# height_cm                       int64
# weight_kg                       int64
# overall                         int64
# potential                       int64
# value_eur                       int64
# team_jersey_number            float64
# pace                          float64
# shooting                      float64
# passing                       float64
# dribbling                     float64
# defending                     float64
# physic                        float64
# gk_diving                     float64
# gk_handling                   float64
# gk_kicking                    float64
# gk_reflexes                   float64
# gk_speed                      float64
# gk_positioning                float64
# ...

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['team_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning']

# %%
df.physic.value_counts(dropna = False)
# Out:
# NaN     2036
# 67.0     726
# 69.0     715
# 70.0     691
# 66.0     686
#         ...
# 89.0       3
# 31.0       2
# 32.0       1
# 90.0       1
# 27.0       1
# Name: physic, Length: 62, dtype: int64

# %%
df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur  team_jersey_number          pace  \
# count  18278.000000  1.827800e+04        18038.000000  16242.000000
# mean      71.546887  2.484038e+06           20.103892     67.700899
# std        6.139669  5.585481e+06           16.603639     11.297656
# ...

# %%
df.loc[[0]]
# Out:
#    sofifa_id                       long_name         dob  age nationality  \
# 0     158023  Lionel Andrés Messi Cuccittini  1987-06-24   32   Argentina
#
#            club preferred_foot  height_cm  weight_kg  overall  ...  \
# 0  FC Barcelona           Left        170         72       94  ...
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         37                        26                   6
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
#
#    goalkeeping_reflexes
# 0                     8
#
# [1 rows x 59 columns]

# %%
df.loc[33:39]
# Out:
#     sofifa_id                     long_name         dob  age nationality  \
# 33     168542     David Josué Jiménez Silva  1986-01-08   33       Spain
# 34     179813  Edinson Roberto Cavani Gómez  1987-02-14   32     Uruguay
# 35     182493                   Diego Godín  1986-02-16   33     Uruguay
# 36     182521                    Toni Kroos  1990-01-04   29     Germany
# 37     188350                    Marco Reus  1989-05-31   30     Germany
# 38     188567     Pierre-Emerick Aubameyang  1989-06-18   30       Gabon
# 39     208722                    Sadio Mané  1992-04-10   27     Senegal
#
#                    club preferred_foot  height_cm  weight_kg  overall  ...  \
# 33      Manchester City           Left        173         67       88  ...
# 34  Paris Saint-Germain          Right        185         77       88  ...
# 35                Inter          Right        187         78       88  ...
# 36          Real Madrid          Right        183         76       88  ...
# ...

# %%
df.drop([0,124,251], axis=0).head()
# Out:
#    sofifa_id                            long_name         dob  age  \
# 1      20801  Cristiano Ronaldo dos Santos Aveiro  1985-02-05   34
# 2     190871        Neymar da Silva Santos Junior  1992-02-05   27
# 3     200389                            Jan Oblak  1993-01-07   26
# 4     183277                          Eden Hazard  1991-01-07   28
# 5     192985                      Kevin De Bruyne  1991-06-28   28
#
#   nationality                 club preferred_foot  height_cm  weight_kg  \
# 1    Portugal             Juventus          Right        187         83
# 2      Brazil  Paris Saint-Germain          Right        175         68
# 3    Slovenia      Atlético Madrid          Right        188         87
# 4     Belgium          Real Madrid          Right        175         74
# 5     Belgium      Manchester City          Right        181         70
#
#    overall  ...  mentality_penalties  mentality_composure  defending_marking  \
# ...

# %%
df.drop(df.index[1:5], axis=0).head(10)
# Out:
#     sofifa_id                       long_name         dob  age  nationality  \
# 0      158023  Lionel Andrés Messi Cuccittini  1987-06-24   32    Argentina
# 5      192985                 Kevin De Bruyne  1991-06-28   28      Belgium
# 6      192448           Marc-André ter Stegen  1992-04-30   27      Germany
# 7      203376                 Virgil van Dijk  1991-07-08   27  Netherlands
# 8      177003                     Luka Modrić  1985-09-09   33      Croatia
# 9      209331            Mohamed  Salah Ghaly  1992-06-15   27        Egypt
# 10     231747                   Kylian Mbappé  1998-12-20   20       France
# 11     201024               Kalidou Koulibaly  1991-06-20   28      Senegal
# 12     202126                      Harry Kane  1993-07-28   25      England
# 13     212831           Alisson Ramses Becker  1992-10-02   26       Brazil
#
#                    club preferred_foot  height_cm  weight_kg  overall  ...  \
# ...

# %%
df[100:].head()
# Out:
#      sofifa_id                       long_name         dob  age nationality  \
# 100     173731               Gareth Frank Bale  1989-07-16   29       Wales
# 101     176676  Marcelo Vieira da Silva Júnior  1988-05-12   31      Brazil
# 102     177413                    Axel  Witsel  1989-01-12   30     Belgium
# 103     191043          Alex Sandro Lobo Silva  1991-01-26   28      Brazil
# 104     192629               Iago Aspas Juncal  1987-08-01   31       Spain
#
#                   club preferred_foot  height_cm  weight_kg  overall  ...  \
# 100        Real Madrid           Left        185         82       85  ...
# 101        Real Madrid           Left        174         75       85  ...
# 102  Borussia Dortmund          Right        186         81       85  ...
# 103           Juventus           Left        180         80       85  ...
# 104           RC Celta           Left        176         67       85  ...
#
# ...

# %%
df.preferred_foot.values
# Out:
# array(['Left', 'Right', 'Right', ..., 'Right', 'Right', 'Right'],
#       dtype=object)

# %%
df[['nationality','club']].values
# Out:
# array([['Argentina', 'FC Barcelona'],
#        ['Portugal', 'Juventus'],
#        ['Brazil', 'Paris Saint-Germain'],
#        ...,
#        ['China PR', 'Hebei China Fortune FC'],
#        ['China PR', 'Shanghai Greenland Shenhua FC'],
#        ['China PR', 'Hebei China Fortune FC']], dtype=object)

# %%
df.preferred_foot.unique()
# Out:
# array(['Left', 'Right'], dtype=object)

# %%
df.preferred_foot.nunique()
# Out:
# 2

# %%
df.preferred_foot.value_counts()
# Out:
# Right    13960
# Left      4318
# Name: preferred_foot, dtype: int64

# %%
df.nationality.value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Jordan                    1
# São Tomé & Príncipe       1
# Macau                     1
# Ethiopia                  1
# Guam                      1
# Name: nationality, Length: 162, dtype: int64

# %%
df.club.value_counts()
# Out:
# Sheffield United           33
# Lazio                      33
# Valencia CF                33
# Athletic Club de Bilbao    33
# Udinese                    33
#                            ..
# Mexico                      1
# Poland                      1
# Śląsk Wrocław               1
# Turkey                      1
# Colombia                    1
# Name: club, Length: 698, dtype: int64

# %%
df.agg(['count','size','nunique'])
# Out:
#          sofifa_id  long_name    dob    age  nationality   club  \
# count        18278      18278  18278  18278        18278  18278
# size         18278      18278  18278  18278        18278  18278
# nunique      18278      18218   6142     27          162    698
#
#          preferred_foot  height_cm  weight_kg  overall  ...  \
# count             18278      18278      18278    18278  ...
# size              18278      18278      18278    18278  ...
# nunique               2         49         56       47  ...
#
#          mentality_penalties  mentality_composure  defending_marking  \
# count                  18278                18278              18278
# size                   18278                18278              18278
# nunique                   86                   85                 92
#
#          defending_standing_tackle  defending_sliding_tackle  \
# count                        18278                     18278
# ...

# %%
df.groupby('preferred_foot').agg(['count','size','nunique'])
# Out:
#                sofifa_id                long_name                   dob  \
#                    count   size nunique     count   size nunique  count
# preferred_foot
# Left                4318   4318    4318      4318   4318    4310   4318
# Right              13960  13960   13960     13960  13960   13921  13960
#
#                                  age  ... goalkeeping_handling  \
#                  size nunique  count  ...              nunique
# preferred_foot                        ...
# Left             4318    2994   4318  ...                   55
# Right           13960    5719  13960  ...                   70
#
#                goalkeeping_kicking                goalkeeping_positioning  \
#                              count   size nunique                   count
# preferred_foot
# Left                          4318   4318      56                    4318
# Right                        13960  13960      78                   13960
#
# ...

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#        sofifa_id             long_name         dob  age     nationality  \
# 7459      199508      Dušan Cvetinović  1988-12-24   30          Serbia
# 6440      200395         Marcelo Silva  1989-03-21   30         Uruguay
# 13550     225976  Sultan Ahmed Mandash  1994-10-17   24    Saudi Arabia
# 14639     248384            Ilia Gruev  2000-05-06   19        Bulgaria
# 1270      243780        이강인 Kangin Lee  2001-02-19   18  Korea Republic
#
#                       club preferred_foot  height_cm  weight_kg  overall  ...  \
# 7459   Yokohama F. Marinos          Right        186         79       68  ...
# 6440        Real Salt Lake          Right        185         82       69  ...
# 13550              Al Ahli          Right        167         63       62  ...
# 14639     SV Werder Bremen           Left        189         74       60  ...
# 1270           Valencia CF           Left        173         61       76  ...
#
# ...

# %%
df.shape
# Out:
# (18278, 59)

# %%
df_sample.shape
# Out:
# (914, 59)

# %% [markdown]
# ## Data Transform

# %%
df_dropped = df.dropna()
df_dropped.head()
# Out:
# Empty DataFrame
# Columns: [sofifa_id, long_name, dob, age, nationality, club, preferred_foot, height_cm, weight_kg, overall, potential, value_eur, team_jersey_number, pace, shooting, passing, dribbling, defending, physic, gk_diving, gk_handling, gk_kicking, gk_reflexes, gk_speed, gk_positioning, attacking_crossing, attacking_finishing, attacking_heading_accuracy, attacking_short_passing, attacking_volleys, skill_dribbling, skill_curve, skill_fk_accuracy, skill_long_passing, skill_ball_control, movement_acceleration, movement_sprint_speed, movement_agility, movement_reactions, movement_balance, power_shot_power, power_jumping, power_stamina, power_strength, power_long_shots, mentality_aggression, mentality_interceptions, mentality_positioning, mentality_vision, mentality_penalties, mentality_composure, defending_marking, defending_standing_tackle, defending_sliding_tackle, goalkeeping_diving, goalkeeping_handling, goalkeeping_kicking, goalkeeping_positioning, goalkeeping_reflexes]
# ...

# %%
#componiendo un poco
aux = df.drop(columns=['gk_diving','gk_handling','gk_kicking','gk_reflexes','gk_speed','gk_positioning'])
df_dropped = aux.dropna()
df_dropped.head()
# Out:
#    sofifa_id                            long_name         dob  age  \
# 0     158023       Lionel Andrés Messi Cuccittini  1987-06-24   32
# 1      20801  Cristiano Ronaldo dos Santos Aveiro  1985-02-05   34
# 2     190871        Neymar da Silva Santos Junior  1992-02-05   27
# 4     183277                          Eden Hazard  1991-01-07   28
# 5     192985                      Kevin De Bruyne  1991-06-28   28
#
#   nationality                 club preferred_foot  height_cm  weight_kg  \
# 0   Argentina         FC Barcelona           Left        170         72
# 1    Portugal             Juventus          Right        187         83
# 2      Brazil  Paris Saint-Germain          Right        175         68
# 4     Belgium          Real Madrid          Right        175         74
# 5     Belgium      Manchester City          Right        181         70
#
#    overall  ...  mentality_penalties  mentality_composure  defending_marking  \
# ...

# %%
df_dropped.shape
# Out:
# (16042, 53)

# %%
df_dropped.dtypes
# Out:
# sofifa_id                       int64
# long_name                      object
# dob                            object
# age                             int64
# nationality                    object
# club                           object
# preferred_foot                 object
# height_cm                       int64
# weight_kg                       int64
# overall                         int64
# potential                       int64
# value_eur                       int64
# team_jersey_number            float64
# pace                          float64
# shooting                      float64
# passing                       float64
# dribbling                     float64
# defending                     float64
# physic                        float64
# attacking_crossing              int64
# attacking_finishing             int64
# attacking_heading_accuracy      int64
# attacking_short_passing         int64
# attacking_volleys               int64
# skill_dribbling                 int64
# ...

# %%
df_dropped['pace'].dtype
# Out:
# dtype('float64')

# %%
df_dropped['pace'].mean()
# Out:
# 67.7022191746665

# %%
df_copy = df.copy()

# %%
df_copy.nationality.value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Jordan                    1
# São Tomé & Príncipe       1
# Macau                     1
# Ethiopia                  1
# Guam                      1
# Name: nationality, Length: 162, dtype: int64

# %% [markdown]
# ## Data summarization

# %%
df_copy['pace'][df_copy['preferred_foot'] == 'Left']
# Out:
# 0        87.0
# 9        93.0
# 16       68.0
# 22       81.0
# 23       83.0
#          ...
# 18230    63.0
# 18237    64.0
# 18238    60.0
# 18244    60.0
# 18246    63.0
# Name: pace, Length: 4318, dtype: float64

# %%
df_copy['pace'][df_copy['preferred_foot'] == 'Left'].mean()
# Out:
# 68.99560761346999

# %%
df_copy[['preferred_foot','nationality','pace']].groupby(['preferred_foot','nationality']).count()
# Out:
#                                   pace
# preferred_foot nationality
# Left           Afghanistan           1
#                Albania              10
#                Algeria              13
#                Angola                5
#                Antigua & Barbuda     1
# ...                                ...
# Right          Venezuela            53
#                Vietnam               1
#                Wales                78
#                Zambia                9
#                Zimbabwe              9
#
# [283 rows x 1 columns]

# %%
df_sample.groupby(['preferred_foot','nationality']).agg([np.sum,np.mean,np.count_nonzero])
# Out:
#                                     sofifa_id                               \
#                                           sum           mean count_nonzero
# preferred_foot nationality
# Left           Argentina              1544116  220588.000000             7
#                Australia               661222  220407.333333             3
#                Austria                 863113  215778.250000             4
#                Belgium                1278780  213130.000000             6
#                Bosnia Herzegovina      242350  242350.000000             1
# ...                                       ...            ...           ...
# Right          United Arab Emirates    247063  247063.000000             1
#                United States          3889972  216109.555556            18
#                Uruguay                1387463  231243.833333             6
#                Venezuela               904013  226003.250000             4
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %%
df_sample.plot(kind='scatter',x='pace',y='dribbling')

# %% [markdown]
# ## Histogramas

# %%
plt.hist(df_sample['preferred_foot'])
plt.title('Derechos vs Zurdos')
# Out:
# Text(0.5, 1.0, 'Derechos vs Zurdos')

# %%
plt.boxplot(df_dropped['pace'], showmeans=True, meanline=True)
plt.ylabel('testecount')
plt.title('Box Plot of pace')
# Out:
# Text(0.5, 1.0, 'Box Plot of pace')
